# %%
#Task 1 - Install Anaconda & Launch Jupyter

#Go to anaconda.com → Download → Install it
#Open Anaconda Navigator → Click Launch under Jupyter Notebook
#Done

# %%
#Task 2 - Change to your real details
print("My name is Raj")
print("My favorite app is Youtube")
# Out:
# My name is Raj
# My favorite app is Youtube

# %%
#Task 3
print("Welcome to Data Science with Python!")
# Out:
# Welcome to Data Science with Python!

# %%
#Task 4
print("Hello from .py file!")
# Out:
# Hello from .py file!
