# %%
#Task 1
age = 20
height = 5.9
name = "Rupanshu"
has_spotify = True

print(age, type(age))
print(height, type(height))
print(name, type(name))
print(has_spotify, type(has_spotify))
# Out:
# 20 <class 'int'>
# 5.9 <class 'float'>
# Rupanshu <class 'str'>
# True <class 'bool'>

# %%
#Task 2
def total_cart_amount(prices):
    total = 0
    for price in prices:
        total += float(price)
    return total

cart = ['199.99', '49', '350.75']
print(total_cart_amount(cart))
# Out:
# 599.74

# %%
#Task 3
score = int(input("Enter your cricket score: "))

if score >= 50:
    print("Half-century!")
else:
    print("Keep going!")
# Out:
# Enter your cricket score:  90
# Half-century!

# %%
#Task 4
is_premium = 'True'

result = is_premium == 'True'
print(result, type(result))
# Out:
# True <class 'bool'>
