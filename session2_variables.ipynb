# %%
#Task 1
item_price = 250
delivery_fee = 30
coupon_discount = 20

print(item_price)
print(delivery_fee)
print(coupon_discount)
# Out:
# 250
# 30
# 20

# %%
#Task 2
product_price = 1200

if product_price > 1000:
    print("Eligible for free delivery")
else:
    print("Delivery charges apply")
# Out:
# Eligible for free delivery

# %%
#task3
# This section checks product price for delivery eligibility

"""
If the product price is above 1000,
the customer gets free delivery.
Otherwise delivery charges apply.
"""

product_price = 1200

# Check if price is above 1000
if product_price > 1000:
    print("Eligible for free delivery")
else:
    print("Delivery charges apply")
# Out:
# Eligible for free delivery

# %%
#task4
team_name = "Mumbai Indians"
runs_scored = 185
overs_played = 20

print(team_name)
print(runs_scored)
print(overs_played)
# Out:
# Mumbai Indians
# 185
# 20
