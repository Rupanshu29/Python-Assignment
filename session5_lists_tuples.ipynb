# %%
#task1
playlist_ids = [101, 202, 303, 404, 505]
print(playlist_ids)
# Out:
# [101, 202, 303, 404, 505]

# %%
#task2
playlist_ids.append(606)
playlist_ids.extend([707, 808])
print(playlist_ids)
# Out:
# [101, 202, 303, 404, 505, 606, 707, 808]

# %%
#task3
removed = playlist_ids.pop()
print("Removed ID:", removed)
print("Remaining playlist:", playlist_ids)
# Out:
# Removed ID: 808
# Remaining playlist: [101, 202, 303, 404, 505, 606, 707]

# %%
#task4
insta_filters = ("Clarendon", "Gingham", "Moon", "Lark")

# Trying to change first filter - this will give error
insta_filters[0] = "Valencia"

# Error: TypeError: 'tuple' object does not support item assignment
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 5
#       1 #task4
#       2 insta_filters = ("Clarendon", "Gingham", "Moon", "Lark")
#       3
#       4 # Trying to change first filter - this will give error
# ----> 5 insta_filters[0] = "Valencia"
#       6
#       7 # Error: TypeError: 'tuple' object does not support item assignment
#
# TypeError: 'tuple' object does not support item assignment

# %%
#task5
# Zomato recent orders change frequently so we use a list
zomato_orders = ["Burger", "Pizza", "Biryani"]

# IPL team names are fixed and never change so we use a tuple
ipl_teams = ("Mumbai Indians", "CSK", "RCB", "KKR")

print("Zomato Orders (list):", zomato_orders)
print("IPL Teams (tuple):", ipl_teams)
# Out:
# Zomato Orders (list): ['Burger', 'Pizza', 'Biryani']
# IPL Teams (tuple): ('Mumbai Indians', 'CSK', 'RCB', 'KKR')
