# %%
#task1
songs = ['Shape Of You', 'Blinding Lights', 'Levitating', 'Senorita']
cleaned = list(map(lambda x: x.lower(), songs))
print(cleaned)
# Out:
# ['shape of you', 'blinding lights', 'levitating', 'senorita']

# %%
#task2
ratings = [4.2, 3.8, 4.5, 2.9, 3.5]
good = list(filter(lambda x: x > 4.0, ratings))
print(good)
# Out:
# [4.2, 4.5]

# %%
#task3
from functools import reduce

cart = [499, 1299, 299, 799]
total = reduce(lambda x, y: x + y, cart)
print("Final Total:", total)
# Out:
# Final Total: 2896

# %%
#task4
def format_followers(n):
    if n >= 1000000:
        return f'{n/1000000:.1f}M'
    elif n >= 1000:
        return f'{n/1000:.1f}K'
    else:
        return str(n)

followers = [950, 1500, 25000, 1200000]
result = list(map(format_followers, followers))
print(result)
# Out:
# ['950', '1.5K', '25.0K', '1.2M']

# %%
#task5
ipl_scores = [101, 98, 120, 77, 88]
even_scores = list(filter(lambda x: x % 2 == 0, ipl_scores))
print(even_scores)
# Out:
# [98, 120, 88]
